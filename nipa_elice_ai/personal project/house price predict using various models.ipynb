# %% [markdown]
# #1.데이터 분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv("train.csv")

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df_train.describe().transpose()
# Out:
#                 count           mean  ...        75%       max
# Id             1460.0     730.500000  ...    1095.25    1460.0
# MSSubClass     1460.0      56.897260  ...      70.00     190.0
# LotFrontage    1201.0      70.049958  ...      80.00     313.0
# LotArea        1460.0   10516.828082  ...   11601.50  215245.0
# OverallQual    1460.0       6.099315  ...       7.00      10.0
# OverallCond    1460.0       5.575342  ...       6.00       9.0
# YearBuilt      1460.0    1971.267808  ...    2000.00    2010.0
# YearRemodAdd   1460.0    1984.865753  ...    2004.00    2010.0
# MasVnrArea     1452.0     103.685262  ...     166.00    1600.0
# BsmtFinSF1     1460.0     443.639726  ...     712.25    5644.0
# BsmtFinSF2     1460.0      46.549315  ...       0.00    1474.0
# BsmtUnfSF      1460.0     567.240411  ...     808.00    2336.0
# TotalBsmtSF    1460.0    1057.429452  ...    1298.25    6110.0
# 1stFlrSF       1460.0    1162.626712  ...    1391.25    4692.0
# 2ndFlrSF       1460.0     346.992466  ...     728.00    2065.0
# LowQualFinSF   1460.0       5.844521  ...       0.00     572.0
# GrLivArea      1460.0    1515.463699  ...    1776.75    5642.0
# BsmtFullBath   1460.0       0.425342  ...       1.00       3.0
# BsmtHalfBath   1460.0       0.057534  ...       0.00       2.0
# FullBath       1460.0       1.565068  ...       2.00       3.0
# HalfBath       1460.0       0.382877  ...       1.00       2.0
# BedroomAbvGr   1460.0       2.866438  ...       3.00       8.0
# KitchenAbvGr   1460.0       1.046575  ...       1.00       3.0
# TotRmsAbvGrd   1460.0       6.517808  ...       7.00      14.0
# Fireplaces     1460.0       0.613014  ...       1.00       3.0
# GarageYrBlt    1379.0    1978.506164  ...    2002.00    2010.0
# GarageCars     1460.0       1.767123  ...       2.00       4.0
# GarageArea     1460.0     472.980137  ...     576.00    1418.0
# WoodDeckSF     1460.0      94.244521  ...     168.00     857.0
# OpenPorchSF    1460.0      46.660274  ...      68.00     547.0
# EnclosedPorch  1460.0      21.954110  ...       0.00     552.0
# 3SsnPorch      1460.0       3.409589  ...       0.00     508.0
# ScreenPorch    1460.0      15.060959  ...       0.00     480.0
# PoolArea       1460.0       2.758904  ...       0.00     738.0
# MiscVal        1460.0      43.489041  ...       0.00   15500.0
# MoSold         1460.0       6.321918  ...       8.00      12.0
# YrSold         1460.0    2007.815753  ...    2009.00    2010.0
# SalePrice      1460.0  180921.195890  ...  214000.00  755000.0
#
# [38 rows x 8 columns]

# %%
#특징들과 SalePrice 관계를 알아보기위하여 한가지 특징을 가지고 boxplot 그려보기
var = 'OverallQual'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
#몇가지 특징들을 뽑아서 scatter로 그려보기
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols], size = 2.5)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #2.데이터 전처리

# %% [markdown]
# ## 2.1 Missing data 처리

# %% [markdown]
# isnull()은 값이 none인 애들은 True, 아닌애들은 False로 바꿈

# %%
df_missing = df_train.isnull().sum()

# %%
df_missing = df_missing.sort_values(ascending=False)

# %%
df_missing
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
#                  ...
# CentralAir          0
# SaleCondition       0
# Heating             0
# TotalBsmtSF         0
# Id                  0
# Length: 81, dtype: int64

# %%
df_missing[df_missing > 0].plot.bar()

# %%
df_missing = df_missing[df_missing >0]

# %%
# missing data가 있는 feature를 제거
df_train = df_train.drop(df_missing.index.tolist(),axis=1)

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType SaleCondition SalePrice
# 0        1          60       RL  ...        WD        Normal    208500
# 1        2          20       RL  ...        WD        Normal    181500
# 2        3          60       RL  ...        WD        Normal    223500
# 3        4          70       RL  ...        WD       Abnorml    140000
# 4        5          60       RL  ...        WD        Normal    250000
# ...    ...         ...      ...  ...       ...           ...       ...
# 1455  1456          60       RL  ...        WD        Normal    175000
# 1456  1457          20       RL  ...        WD        Normal    210000
# 1457  1458          70       RL  ...        WD        Normal    266500
# 1458  1459          20       RL  ...        WD        Normal    142125
# 1459  1460          20       RL  ...        WD        Normal    147500
#
# [1460 rows x 62 columns]

# %%
# missing data가 있는지 재확인
df_train.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# ##2.2 Numeric 데이터 구분

# %%
numeric = [df_train.dtypes[f] for f in df_train.columns]
numeric
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64')]

# %%
numeric = [f for f in df_train.columns if df_train.dtypes[f] !='object']
numeric.remove('Id')
numeric.remove('SalePrice')

# %% [markdown]
# ## 2.3 Categorical 데이터를 processing

# %%
categorical = [f for f in df_train.columns if df_train.dtypes[f] =='object']

# %%
categorical
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %% [markdown]
# 카테고릭한 값들을 숫자로 변환시키는 작업을 모든 feature에 대하여 함수를 만들어 진행

# %%
def add_rank_feature (feature_name, rank_feature_name):
  df_order = pd.DataFrame()
  df_order['val'] = df_train[feature_name].unique()
  df_order.index = df_order.val

  df_order['mean_price'] = df_train[[feature_name, 'SalePrice']].groupby(feature_name).mean()['SalePrice']
  df_order['rank'] = range(1,len(df_order)+1)
  df_order = df_order['rank'].to_dict()

  df_train[feature_name + '_rank'] = df_train.apply(lambda x: df_order[x[feature_name]],axis=1)

# %%
rank_features = []
for feature_name in categorical:
  
  rank_feature_name = feature_name + '_rank'
  print(feature_name, '-->', rank_feature_name)
  add_rank_feature(feature_name, rank_feature_name)

  rank_features.append(rank_feature_name)
# Out:
# MSZoning --> MSZoning_rank
# Street --> Street_rank
# LotShape --> LotShape_rank
# LandContour --> LandContour_rank
# Utilities --> Utilities_rank
# LotConfig --> LotConfig_rank
# LandSlope --> LandSlope_rank
# Neighborhood --> Neighborhood_rank
# Condition1 --> Condition1_rank
# Condition2 --> Condition2_rank
# BldgType --> BldgType_rank
# HouseStyle --> HouseStyle_rank
# RoofStyle --> RoofStyle_rank
# RoofMatl --> RoofMatl_rank
# Exterior1st --> Exterior1st_rank
# Exterior2nd --> Exterior2nd_rank
# ExterQual --> ExterQual_rank
# ExterCond --> ExterCond_rank
# Foundation --> Foundation_rank
# Heating --> Heating_rank
# HeatingQC --> HeatingQC_rank
# CentralAir --> CentralAir_rank
# KitchenQual --> KitchenQual_rank
# Functional --> Functional_rank
# PavedDrive --> PavedDrive_rank
# SaleType --> SaleType_rank
# SaleCondition --> SaleCondition_rank

# %%
df_train
# Out:
#         Id  MSSubClass  ... SaleType_rank  SaleCondition_rank
# 0        1          60  ...             1                   1
# 1        2          20  ...             1                   1
# 2        3          60  ...             1                   1
# 3        4          70  ...             1                   2
# 4        5          60  ...             1                   1
# ...    ...         ...  ...           ...                 ...
# 1455  1456          60  ...             1                   1
# 1456  1457          20  ...             1                   1
# 1457  1458          70  ...             1                   1
# 1458  1459          20  ...             1                   1
# 1459  1460          20  ...             1                   1
#
# [1460 rows x 89 columns]

# %%
df_processed = df_train[rank_features + numeric]

# %%
df_processed
# Out:
#       MSZoning_rank  Street_rank  LotShape_rank  ...  MiscVal  MoSold  YrSold
# 0                 1            1              1  ...        0       2    2008
# 1                 1            1              1  ...        0       5    2007
# 2                 1            1              2  ...        0       9    2008
# 3                 1            1              2  ...        0       2    2006
# 4                 1            1              2  ...        0      12    2008
# ...             ...          ...            ...  ...      ...     ...     ...
# 1455              1            1              1  ...        0       8    2007
# 1456              1            1              1  ...        0       2    2010
# 1457              1            1              1  ...     2500       5    2010
# 1458              1            1              1  ...        0       4    2010
# 1459              1            1              1  ...        0       6    2008
#
# [1460 rows x 60 columns]

# %%
df_processed['SalePrice'] = df_train['SalePrice']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_processed
# Out:
#       MSZoning_rank  Street_rank  LotShape_rank  ...  MoSold  YrSold  SalePrice
# 0                 1            1              1  ...       2    2008     208500
# 1                 1            1              1  ...       5    2007     181500
# 2                 1            1              2  ...       9    2008     223500
# 3                 1            1              2  ...       2    2006     140000
# 4                 1            1              2  ...      12    2008     250000
# ...             ...          ...            ...  ...     ...     ...        ...
# 1455              1            1              1  ...       8    2007     175000
# 1456              1            1              1  ...       2    2010     210000
# 1457              1            1              1  ...       5    2010     266500
# 1458              1            1              1  ...       4    2010     142125
# 1459              1            1              1  ...       6    2008     147500
#
# [1460 rows x 61 columns]

# %% [markdown]
# 마지막으로 Correlation matrix를 뽑아본다면

# %%
corrmat = df_processed.corr()

# %%
f, ax = plt.subplots(figsize=(24,18))
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
df_features = corrmat.sort_values(by=['SalePrice'])['SalePrice']

# %%
df_features[-50:]
# Out:
# Exterior1st_rank     -0.120586
# MSZoning_rank        -0.116047
# KitchenQual_rank     -0.114746
# BldgType_rank        -0.112611
# Functional_rank      -0.108367
# Heating_rank         -0.106673
# MSSubClass           -0.084284
# OverallCond          -0.077856
# Condition1_rank      -0.044820
# Street_rank          -0.041036
# YrSold               -0.028923
# LowQualFinSF         -0.025606
# MiscVal              -0.021190
# BsmtHalfBath         -0.016844
# Utilities_rank       -0.014314
# BsmtFinSF2           -0.011378
# Condition2_rank      -0.004833
# RoofMatl_rank         0.035820
# 3SsnPorch             0.044584
# MoSold                0.046432
# LandSlope_rank        0.051152
# SaleType_rank         0.072896
# LandContour_rank      0.092009
# PoolArea              0.092404
# LotConfig_rank        0.109106
# ScreenPorch           0.111447
# SaleCondition_rank    0.142503
# RoofStyle_rank        0.159332
# BedroomAbvGr          0.168213
# BsmtUnfSF             0.214479
# BsmtFullBath          0.227122
# LotArea               0.263843
# LotShape_rank         0.267759
# HalfBath              0.284108
# OpenPorchSF           0.315856
# 2ndFlrSF              0.319334
# WoodDeckSF            0.324413
# BsmtFinSF1            0.386420
# Fireplaces            0.466929
# YearRemodAdd          0.507101
# YearBuilt             0.522897
# TotRmsAbvGrd          0.533723
# FullBath              0.560664
# 1stFlrSF              0.605852
# TotalBsmtSF           0.613581
# GarageArea            0.623431
# GarageCars            0.640409
# GrLivArea             0.708624
# OverallQual           0.790982
# SalePrice             1.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## 2.4 Train test split

# %% [markdown]
# df_train 전체를 학습을 시키지는 않음
#
# 학습이 잘 되었는지 평가용도 만들어야 하기 때문
#
# 따라서 df_train을 학습용과 평가용 두가지로 나눠서 만들어놓을 것임

# %%
#앞에서 찾은 컬럼과 Sale price간의 correlation값이 너무 작은 놈들은 제외 하겠음
NUM_FEATURES = 15

# %%
from sklearn.model_selection import train_test_split

# %%
df_features[-NUM_FEATURES-1:-1].index.tolist()
# Out:
# ['OpenPorchSF',
#  '2ndFlrSF',
#  'WoodDeckSF',
#  'BsmtFinSF1',
#  'Fireplaces',
#  'YearRemodAdd',
#  'YearBuilt',
#  'TotRmsAbvGrd',
#  'FullBath',
#  '1stFlrSF',
#  'TotalBsmtSF',
#  'GarageArea',
#  'GarageCars',
#  'GrLivArea',
#  'OverallQual']

# %%
df_processed
# Out:
#       MSZoning_rank  Street_rank  LotShape_rank  ...  MoSold  YrSold  SalePrice
# 0                 1            1              1  ...       2    2008     208500
# 1                 1            1              1  ...       5    2007     181500
# 2                 1            1              2  ...       9    2008     223500
# 3                 1            1              2  ...       2    2006     140000
# 4                 1            1              2  ...      12    2008     250000
# ...             ...          ...            ...  ...     ...     ...        ...
# 1455              1            1              1  ...       8    2007     175000
# 1456              1            1              1  ...       2    2010     210000
# 1457              1            1              1  ...       5    2010     266500
# 1458              1            1              1  ...       4    2010     142125
# 1459              1            1              1  ...       6    2008     147500
#
# [1460 rows x 61 columns]

# %%
X = df_processed[df_features[-NUM_FEATURES-1:-1].index.tolist()]
y = df_processed['SalePrice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
#k fold validation 때 k개 각각의 데이터를 전처리하기 귀찮으니 전처리를 먼저 하고 간다
# min_max scaler는 각각의 칼럼의 범위가 제각각이니까 0-1사이로 맞춰주고 한다
#data preprocessing
X_min_max_scaler = MinMaxScaler()
X_min_max_scaler.fit(X)
scaled_X = X_min_max_scaler.transform(X)

y_min_max_scaler = MinMaxScaler()
y_min_max_scaler.fit(np.array(y).reshape(-1,1))
scaled_y = y_min_max_scaler.transform(np.array(y).reshape(-1,1))

# %%
from sklearn.model_selection import KFold
# K-fold cross validation
K = 10
kf = KFold(n_splits=K)

# %%
print(scaled_X,scaled_X.shape)
print(scaled_y)
# Out:
# [[0.11151737 0.41355932 0.         ... 0.5        0.25923135 0.66666667]
#  [0.         0.         0.34772462 ... 0.5        0.17483044 0.55555556]
#  [0.07678245 0.41937046 0.         ... 0.5        0.27354936 0.66666667]
#  ...
#  [0.10968921 0.55786925 0.         ... 0.25       0.37792012 0.66666667]
#  [0.         0.         0.42707118 ... 0.25       0.14016579 0.44444444]
#  [0.12431444 0.         0.8588098  ... 0.25       0.17370008 0.44444444]] (1460, 15)
# [[0.24107763]
#  [0.20358284]
#  [0.26190807]
#  ...
#  [0.321622  ]
#  [0.14890293]
#  [0.15636717]]

# %% [markdown]
# #3.여러 모델 적용하기

# %%
# 라벨 값이 연속된 값인 회귀문제라서 평가 지표로 RMSE를 사용할 것이다.
models = []

# %% [markdown]
# ##3.1 Linear regression (Lasso)
# y = Xw 선형모델

# %%
from sklearn.linear_model import Lasso
from sklearn import metrics
rmses = []
for train_index, test_index in kf.split(scaled_X):
  #print("Test:", test_index, "trains:", train_index)

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = Lasso()
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))  #0-1
  pred = y_min_max_scaler.inverse_transform(pred)  #원상복구된 스케일
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# 68479.61848137801
# ===============================
# 80011.92820033105
# ===============================
# 79275.65958882873
# ===============================
# 82868.15912800275
# ===============================
# 96386.20490927555
# ===============================
# 76808.56629102639
# ===============================
# 72198.44861652121
# ===============================
# 71213.04254017191
# ===============================
# 90347.61467595294
# ===============================
# 72613.27897372228
# ===============================
# average rmse: 79020.25214052107

# %% [markdown]
# ##3.2 MLP(Multi-layer Perceptron)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]


  #training
  model = keras.Sequential(
     [
      keras.Input(shape=scaled_X_train.shape[-1]),
      layers.Dense(96, activation='relu'),
      layers.Dense(48, activation='relu'),
      layers.Dense(1)
     ]
  )

  model.compile(loss = 'mse', optimizer = 'adam')
  early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7)
  model.fit(scaled_X_train, scaled_y_train, batch_size=4, epochs=150,
            callbacks=[early_stopping_callback], validation_split=0.05)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))  #0-1
  pred = y_min_max_scaler.inverse_transform(pred)  #원상복구된 스케일
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0057 - val_loss: 0.0013
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 17/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 18/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 19/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# 30514.49800472787
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0048 - val_loss: 0.0016
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 17/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 18/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 9.9145e-04
# Epoch 19/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 20/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 21/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 22/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 23/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 24/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 25/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0014
# 28548.6514289074
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0015
# 29305.079074541918
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 17/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 18/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 19/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 20/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 21/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 22/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 23/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 24/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 25/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 26/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 27/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 28/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 29/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0012
# 50124.29951267045
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 17/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 18/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 19/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 20/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 21/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 22/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 23/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 24/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 25/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 26/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 27/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 28/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 29/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 30/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# 29626.022602393306
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0104 - val_loss: 0.0024
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# 34174.963495003096
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 17/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 18/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 19/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 20/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 21/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 22/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# 23574.72767327534
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 9.6591e-04
# Epoch 17/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 18/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 19/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 20/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 21/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 22/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 23/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 9.4422e-04
# Epoch 24/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 9.9860e-04
# Epoch 25/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 26/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 27/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 28/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 29/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 30/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# 28947.37574323186
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# 59941.131333471036
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0044 - val_loss: 0.0087
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0068
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0087
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0099
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0105
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0151
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0120
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0100
# 27784.337218449415
# ===============================
# average rmse: 34254.10860866717

# %% [markdown]
# ##3.3 Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = DecisionTreeRegressor(random_state = 0)
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))
  pred = y_min_max_scaler.inverse_transform(pred)
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# 39753.62430595359
# ===============================
# 40661.42306550926
# ===============================
# 38419.454854368865
# ===============================
# 48350.89454352677
# ===============================
# 42820.177703076166
# ===============================
# 33427.351132825796
# ===============================
# 30544.598423329542
# ===============================
# 39578.47220682006
# ===============================
# 48950.17075536562
# ===============================
# 37045.93036226546
# ===============================
# average rmse: 39955.20973530411

# %% [markdown]
# ##3.4 Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = RandomForestRegressor(random_state = 0, n_estimators = 200)
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))
  pred = y_min_max_scaler.inverse_transform(pred)
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 27675.179933119005
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 28398.36379383487
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 23850.872433587134
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 41400.11484400066
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 31498.772414599076
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 27164.193166711215
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 24578.407068970435
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 24678.13288110968
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 36968.32144364733
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 26525.46416080235
# ===============================
# average rmse: 29273.78221403818

# %% [markdown]
# ##3.5 AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor
rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = AdaBoostRegressor(random_state = 0, n_estimators = 200)
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))
  pred = y_min_max_scaler.inverse_transform(pred)
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 31920.705996605775
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 34965.325983329014
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 29774.04593944251
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 43701.873583602035
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 39380.99766277385
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 34484.814550743824
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 31506.68566944809
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 32706.715731086922
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 38152.989426034444
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 35268.19942050678
# ===============================
# average rmse: 35186.235396357326

# %% [markdown]
# ##3.6 XGBoost

# %%
from xgboost import XGBRegressor
rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = XGBRegressor(random_state = 0, n_estimators = 200)
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))
  pred = y_min_max_scaler.inverse_transform(pred)
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# [05:43:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 24405.561644290126
# ===============================
# [05:43:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 26709.98444825083
# ===============================
# [05:43:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 25161.113550953
# ===============================
# [05:43:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 37756.76998222338
# ===============================
# [05:43:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 30804.731397426076
# ===============================
# [05:43:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 26356.734412051854
# ===============================
# [05:43:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 29570.918088054954
# ===============================
# [05:43:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 24383.726575024124
# ===============================
# [05:43:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 28993.890495956213
# ===============================
# [05:43:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 25574.58614570736
# ===============================
# average rmse: 27971.801673993796

# %% [markdown]
# #4.모델 비교 및 결론

# %%
model_compare = pd.DataFrame(models, columns = ['RMSE'],index=['Linear','MLP','Decision Tree','Random Forest','AdaBoost','XGBoost'])
model_compare.sort_values(by = 'RMSE',ascending=True)
# Out:
#                        RMSE
# XGBoost        27971.801674
# Random Forest  29273.782214
# MLP            34254.108609
# AdaBoost       35186.235396
# Decision Tree  39955.209735
# Linear         79020.252141

# %% [markdown]
# XGBoost를 사용했을때 오차가 제일 낮게 나왔음
