# %% [markdown]
# #1.데이터 분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv("train.csv")

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df_train.describe().transpose()
# Out:
#                 count           mean  ...        75%       max
# Id             1460.0     730.500000  ...    1095.25    1460.0
# MSSubClass     1460.0      56.897260  ...      70.00     190.0
# LotFrontage    1201.0      70.049958  ...      80.00     313.0
# LotArea        1460.0   10516.828082  ...   11601.50  215245.0
# OverallQual    1460.0       6.099315  ...       7.00      10.0
# OverallCond    1460.0       5.575342  ...       6.00       9.0
# YearBuilt      1460.0    1971.267808  ...    2000.00    2010.0
# YearRemodAdd   1460.0    1984.865753  ...    2004.00    2010.0
# MasVnrArea     1452.0     103.685262  ...     166.00    1600.0
# BsmtFinSF1     1460.0     443.639726  ...     712.25    5644.0
# BsmtFinSF2     1460.0      46.549315  ...       0.00    1474.0
# BsmtUnfSF      1460.0     567.240411  ...     808.00    2336.0
# TotalBsmtSF    1460.0    1057.429452  ...    1298.25    6110.0
# 1stFlrSF       1460.0    1162.626712  ...    1391.25    4692.0
# 2ndFlrSF       1460.0     346.992466  ...     728.00    2065.0
# LowQualFinSF   1460.0       5.844521  ...       0.00     572.0
# GrLivArea      1460.0    1515.463699  ...    1776.75    5642.0
# BsmtFullBath   1460.0       0.425342  ...       1.00       3.0
# BsmtHalfBath   1460.0       0.057534  ...       0.00       2.0
# FullBath       1460.0       1.565068  ...       2.00       3.0
# HalfBath       1460.0       0.382877  ...       1.00       2.0
# BedroomAbvGr   1460.0       2.866438  ...       3.00       8.0
# KitchenAbvGr   1460.0       1.046575  ...       1.00       3.0
# TotRmsAbvGrd   1460.0       6.517808  ...       7.00      14.0
# Fireplaces     1460.0       0.613014  ...       1.00       3.0
# GarageYrBlt    1379.0    1978.506164  ...    2002.00    2010.0
# GarageCars     1460.0       1.767123  ...       2.00       4.0
# GarageArea     1460.0     472.980137  ...     576.00    1418.0
# WoodDeckSF     1460.0      94.244521  ...     168.00     857.0
# OpenPorchSF    1460.0      46.660274  ...      68.00     547.0
# EnclosedPorch  1460.0      21.954110  ...       0.00     552.0
# 3SsnPorch      1460.0       3.409589  ...       0.00     508.0
# ScreenPorch    1460.0      15.060959  ...       0.00     480.0
# PoolArea       1460.0       2.758904  ...       0.00     738.0
# MiscVal        1460.0      43.489041  ...       0.00   15500.0
# MoSold         1460.0       6.321918  ...       8.00      12.0
# YrSold         1460.0    2007.815753  ...    2009.00    2010.0
# SalePrice      1460.0  180921.195890  ...  214000.00  755000.0
#
# [38 rows x 8 columns]

# %%
#특징들과 SalePrice 관계를 알아보기위하여 한가지 특징을 가지고 boxplot 그려보기
var = 'OverallQual'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
#몇가지 특징들을 뽑아서 scatter로 그려보기
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols], size = 2.5)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #2.데이터 전처리

# %% [markdown]
# ## 2.1 Missing data 처리

# %% [markdown]
# isnull()은 값이 none인 애들은 True, 아닌애들은 False로 바꿈

# %%
df_missing = df_train.isnull().sum()

# %%
df_missing = df_missing.sort_values(ascending=False)

# %%
df_missing
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
#                  ...
# CentralAir          0
# SaleCondition       0
# Heating             0
# TotalBsmtSF         0
# Id                  0
# Length: 81, dtype: int64

# %%
df_missing[df_missing > 0].plot.bar()

# %%
df_missing = df_missing[df_missing >0]

# %%
# missing data가 있는 feature를 제거
df_train = df_train.drop(df_missing.index.tolist(),axis=1)

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType SaleCondition SalePrice
# 0        1          60       RL  ...        WD        Normal    208500
# 1        2          20       RL  ...        WD        Normal    181500
# 2        3          60       RL  ...        WD        Normal    223500
# 3        4          70       RL  ...        WD       Abnorml    140000
# 4        5          60       RL  ...        WD        Normal    250000
# ...    ...         ...      ...  ...       ...           ...       ...
# 1455  1456          60       RL  ...        WD        Normal    175000
# 1456  1457          20       RL  ...        WD        Normal    210000
# 1457  1458          70       RL  ...        WD        Normal    266500
# 1458  1459          20       RL  ...        WD        Normal    142125
# 1459  1460          20       RL  ...        WD        Normal    147500
#
# [1460 rows x 62 columns]

# %%
# missing data가 있는지 재확인
df_train.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# ##2.2 Numeric 데이터 구분

# %%
numeric = [df_train.dtypes[f] for f in df_train.columns]
numeric
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64')]

# %%
numeric = [f for f in df_train.columns if df_train.dtypes[f] !='object']
numeric.remove('Id')
numeric.remove('SalePrice')

# %% [markdown]
# ## 2.3 Categorical 데이터를 processing

# %%
categorical = [f for f in df_train.columns if df_train.dtypes[f] =='object']

# %%
categorical
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %% [markdown]
# 카테고릭한 값들을 숫자로 변환시키는 작업을 모든 feature에 대하여 함수를 만들어 진행

# %%
category_maps = []
def add_rank_feature (feature_name, rank_feature_name):
  df_order = pd.DataFrame()
  df_order['val'] = df_train[feature_name].unique()
  df_order.index = df_order.val

  df_order['mean_price'] = df_train[[feature_name, 'SalePrice']].groupby(feature_name).mean()['SalePrice']
  df_order['rank'] = range(1,len(df_order)+1)
  df_order = df_order['rank'].to_dict()

  category_maps.append(df_order)

  df_train[feature_name + '_rank'] = df_train.apply(lambda x: df_order[x[feature_name]],axis=1)

# %%
rank_features = []
for feature_name in categorical:
  
  rank_feature_name = feature_name + '_rank'
  print(feature_name, '-->', rank_feature_name)
  add_rank_feature(feature_name, rank_feature_name)

  rank_features.append(rank_feature_name)
# Out:
# MSZoning --> MSZoning_rank
# Street --> Street_rank
# LotShape --> LotShape_rank
# LandContour --> LandContour_rank
# Utilities --> Utilities_rank
# LotConfig --> LotConfig_rank
# LandSlope --> LandSlope_rank
# Neighborhood --> Neighborhood_rank
# Condition1 --> Condition1_rank
# Condition2 --> Condition2_rank
# BldgType --> BldgType_rank
# HouseStyle --> HouseStyle_rank
# RoofStyle --> RoofStyle_rank
# RoofMatl --> RoofMatl_rank
# Exterior1st --> Exterior1st_rank
# Exterior2nd --> Exterior2nd_rank
# ExterQual --> ExterQual_rank
# ExterCond --> ExterCond_rank
# Foundation --> Foundation_rank
# Heating --> Heating_rank
# HeatingQC --> HeatingQC_rank
# CentralAir --> CentralAir_rank
# KitchenQual --> KitchenQual_rank
# Functional --> Functional_rank
# PavedDrive --> PavedDrive_rank
# SaleType --> SaleType_rank
# SaleCondition --> SaleCondition_rank

# %%
df_train
# Out:
#         Id  MSSubClass  ... SaleType_rank  SaleCondition_rank
# 0        1          60  ...             1                   1
# 1        2          20  ...             1                   1
# 2        3          60  ...             1                   1
# 3        4          70  ...             1                   2
# 4        5          60  ...             1                   1
# ...    ...         ...  ...           ...                 ...
# 1455  1456          60  ...             1                   1
# 1456  1457          20  ...             1                   1
# 1457  1458          70  ...             1                   1
# 1458  1459          20  ...             1                   1
# 1459  1460          20  ...             1                   1
#
# [1460 rows x 89 columns]

# %%
df_processed = df_train[rank_features + numeric]

# %%
df_processed
# Out:
#       MSZoning_rank  Street_rank  LotShape_rank  ...  MiscVal  MoSold  YrSold
# 0                 1            1              1  ...        0       2    2008
# 1                 1            1              1  ...        0       5    2007
# 2                 1            1              2  ...        0       9    2008
# 3                 1            1              2  ...        0       2    2006
# 4                 1            1              2  ...        0      12    2008
# ...             ...          ...            ...  ...      ...     ...     ...
# 1455              1            1              1  ...        0       8    2007
# 1456              1            1              1  ...        0       2    2010
# 1457              1            1              1  ...     2500       5    2010
# 1458              1            1              1  ...        0       4    2010
# 1459              1            1              1  ...        0       6    2008
#
# [1460 rows x 60 columns]

# %%
df_processed['SalePrice'] = df_train['SalePrice']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_processed
# Out:
#       MSZoning_rank  Street_rank  LotShape_rank  ...  MoSold  YrSold  SalePrice
# 0                 1            1              1  ...       2    2008     208500
# 1                 1            1              1  ...       5    2007     181500
# 2                 1            1              2  ...       9    2008     223500
# 3                 1            1              2  ...       2    2006     140000
# 4                 1            1              2  ...      12    2008     250000
# ...             ...          ...            ...  ...     ...     ...        ...
# 1455              1            1              1  ...       8    2007     175000
# 1456              1            1              1  ...       2    2010     210000
# 1457              1            1              1  ...       5    2010     266500
# 1458              1            1              1  ...       4    2010     142125
# 1459              1            1              1  ...       6    2008     147500
#
# [1460 rows x 61 columns]

# %% [markdown]
# 마지막으로 Correlation matrix를 뽑아본다면

# %%
corrmat = df_processed.corr()

# %%
f, ax = plt.subplots(figsize=(24,18))
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
df_features = corrmat.sort_values(by=['SalePrice'])['SalePrice']

# %%
df_features[-50:]
# Out:
# Exterior1st_rank     -0.120586
# MSZoning_rank        -0.116047
# KitchenQual_rank     -0.114746
# BldgType_rank        -0.112611
# Functional_rank      -0.108367
# Heating_rank         -0.106673
# MSSubClass           -0.084284
# OverallCond          -0.077856
# Condition1_rank      -0.044820
# Street_rank          -0.041036
# YrSold               -0.028923
# LowQualFinSF         -0.025606
# MiscVal              -0.021190
# BsmtHalfBath         -0.016844
# Utilities_rank       -0.014314
# BsmtFinSF2           -0.011378
# Condition2_rank      -0.004833
# RoofMatl_rank         0.035820
# 3SsnPorch             0.044584
# MoSold                0.046432
# LandSlope_rank        0.051152
# SaleType_rank         0.072896
# LandContour_rank      0.092009
# PoolArea              0.092404
# LotConfig_rank        0.109106
# ScreenPorch           0.111447
# SaleCondition_rank    0.142503
# RoofStyle_rank        0.159332
# BedroomAbvGr          0.168213
# BsmtUnfSF             0.214479
# BsmtFullBath          0.227122
# LotArea               0.263843
# LotShape_rank         0.267759
# HalfBath              0.284108
# OpenPorchSF           0.315856
# 2ndFlrSF              0.319334
# WoodDeckSF            0.324413
# BsmtFinSF1            0.386420
# Fireplaces            0.466929
# YearRemodAdd          0.507101
# YearBuilt             0.522897
# TotRmsAbvGrd          0.533723
# FullBath              0.560664
# 1stFlrSF              0.605852
# TotalBsmtSF           0.613581
# GarageArea            0.623431
# GarageCars            0.640409
# GrLivArea             0.708624
# OverallQual           0.790982
# SalePrice             1.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## 2.4 Train test split

# %% [markdown]
# df_train 전체를 학습을 시키지는 않음
#
# 학습이 잘 되었는지 평가용도 만들어야 하기 때문
#
# 따라서 df_train을 학습용과 평가용 두가지로 나눠서 만들어놓을 것임

# %%
#앞에서 찾은 컬럼과 Sale price간의 correlation값이 너무 작은 놈들은 제외 하겠음
NUM_FEATURES = 15

# %%
from sklearn.model_selection import train_test_split

# %%
df_features[-NUM_FEATURES-1:-1].index.tolist()
# Out:
# ['OpenPorchSF',
#  '2ndFlrSF',
#  'WoodDeckSF',
#  'BsmtFinSF1',
#  'Fireplaces',
#  'YearRemodAdd',
#  'YearBuilt',
#  'TotRmsAbvGrd',
#  'FullBath',
#  '1stFlrSF',
#  'TotalBsmtSF',
#  'GarageArea',
#  'GarageCars',
#  'GrLivArea',
#  'OverallQual']

# %%
df_processed
# Out:
#       MSZoning_rank  Street_rank  LotShape_rank  ...  MoSold  YrSold  SalePrice
# 0                 1            1              1  ...       2    2008     208500
# 1                 1            1              1  ...       5    2007     181500
# 2                 1            1              2  ...       9    2008     223500
# 3                 1            1              2  ...       2    2006     140000
# 4                 1            1              2  ...      12    2008     250000
# ...             ...          ...            ...  ...     ...     ...        ...
# 1455              1            1              1  ...       8    2007     175000
# 1456              1            1              1  ...       2    2010     210000
# 1457              1            1              1  ...       5    2010     266500
# 1458              1            1              1  ...       4    2010     142125
# 1459              1            1              1  ...       6    2008     147500
#
# [1460 rows x 61 columns]

# %%
X = df_processed[df_features[-NUM_FEATURES-1:-1].index.tolist()]
y = df_processed['SalePrice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
#k fold validation 때 k개 각각의 데이터를 전처리하기 귀찮으니 전처리를 먼저 하고 간다
# min_max scaler는 각각의 칼럼의 범위가 제각각이니까 0-1사이로 맞춰주고 한다
#data preprocessing
X_min_max_scaler = MinMaxScaler()
X_min_max_scaler.fit(X)
scaled_X = X_min_max_scaler.transform(X)

y_min_max_scaler = MinMaxScaler()
y_min_max_scaler.fit(np.array(y).reshape(-1,1))
scaled_y = y_min_max_scaler.transform(np.array(y).reshape(-1,1))

# %%
from sklearn.model_selection import KFold
# K-fold cross validation
K = 10
kf = KFold(n_splits=K)

# %%
print(scaled_X,scaled_X.shape)
print(scaled_y)
# Out:
# [[0.11151737 0.41355932 0.         ... 0.5        0.25923135 0.66666667]
#  [0.         0.         0.34772462 ... 0.5        0.17483044 0.55555556]
#  [0.07678245 0.41937046 0.         ... 0.5        0.27354936 0.66666667]
#  ...
#  [0.10968921 0.55786925 0.         ... 0.25       0.37792012 0.66666667]
#  [0.         0.         0.42707118 ... 0.25       0.14016579 0.44444444]
#  [0.12431444 0.         0.8588098  ... 0.25       0.17370008 0.44444444]] (1460, 15)
# [[0.24107763]
#  [0.20358284]
#  [0.26190807]
#  ...
#  [0.321622  ]
#  [0.14890293]
#  [0.15636717]]

# %% [markdown]
# #3.여러 모델 적용하기

# %%
# 라벨 값이 연속된 값인 회귀문제라서 평가 지표로 RMSE를 사용할 것이다.
models = []

# %% [markdown]
# ##3.1 Linear regression (Lasso)
# y = Xw 선형모델

# %%
from sklearn.linear_model import Lasso
from sklearn import metrics
rmses = []
for train_index, test_index in kf.split(scaled_X):
  #print("Test:", test_index, "trains:", train_index)

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = Lasso()
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))  #0-1
  pred = y_min_max_scaler.inverse_transform(pred)  #원상복구된 스케일
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# 68479.61848137801
# ===============================
# 80011.92820033105
# ===============================
# 79275.65958882873
# ===============================
# 82868.15912800275
# ===============================
# 96386.20490927555
# ===============================
# 76808.56629102639
# ===============================
# 72198.44861652121
# ===============================
# 71213.04254017191
# ===============================
# 90347.61467595294
# ===============================
# 72613.27897372228
# ===============================
# average rmse: 79020.25214052107

# %% [markdown]
# ##3.2 MLP(Multi-layer Perceptron)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]


  #training
  model = keras.Sequential(
     [
      keras.Input(shape=scaled_X_train.shape[-1]),
      layers.Dense(96, activation='relu'),
      layers.Dense(48, activation='relu'),
      layers.Dense(1)
     ]
  )

  model.compile(loss = 'mse', optimizer = 'adam')
  early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=7)
  model.fit(scaled_X_train, scaled_y_train, batch_size=4, epochs=150,
            callbacks=[early_stopping_callback], validation_split=0.05)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))  #0-1
  pred = y_min_max_scaler.inverse_transform(pred)  #원상복구된 스케일
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 9/150
# 312/312 [==============================] - 0s 1ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 11/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 13/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 14/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 15/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 17/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 18/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# 27930.72567861442
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 2/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 4/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 5/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 6/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 7/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 9.8428e-04
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 9/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 10/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 12/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# 29678.012366220904
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 2/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 3/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 4/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 5/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 6/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 8/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 14/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0020
# 33343.43411386869
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 12/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0015
# 46915.38746755043
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0057 - val_loss: 0.0013
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 5/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 9/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0016
# 36908.03932737537
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 4/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 5/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 7/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 9/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 10/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 11/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 12/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 16/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 17/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 9.9042e-04
# Epoch 18/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 19/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 20/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 21/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 22/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 23/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 24/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0014
# 27338.845378663093
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 7/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 8/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 9/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 11/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0016
# 29191.53258818219
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0068 - val_loss: 0.0017
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 8/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 9/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 12/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0015
# 29021.34947767906
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 5/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 7/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 11/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 14/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 15/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 17/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 18/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 19/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 20/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 21/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 22/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 23/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 24/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 25/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 26/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 27/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 28/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 29/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 30/150
# 312/312 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 31/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 32/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 0.0020
# 43511.210691442095
# ===============================
# Epoch 1/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0048 - val_loss: 0.0097
# Epoch 2/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0027 - val_loss: 0.0108
# Epoch 3/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0024 - val_loss: 0.0126
# Epoch 4/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0022 - val_loss: 0.0130
# Epoch 5/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0023 - val_loss: 0.0091
# Epoch 6/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0167
# Epoch 7/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0021 - val_loss: 0.0105
# Epoch 8/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 9/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0019 - val_loss: 0.0078
# Epoch 10/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0018 - val_loss: 0.0098
# Epoch 11/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0129
# Epoch 12/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0149
# Epoch 13/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0110
# Epoch 14/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0116
# Epoch 15/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0016 - val_loss: 0.0157
# Epoch 16/150
# 312/312 [==============================] - 1s 2ms/step - loss: 0.0017 - val_loss: 0.0091
# 26455.610424303355
# ===============================
# average rmse: 33029.41475138995

# %% [markdown]
# ##3.3 Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = DecisionTreeRegressor(random_state = 0)
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))
  pred = y_min_max_scaler.inverse_transform(pred)
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# 39156.22867586252
# ===============================
# 40842.68766015276
# ===============================
# 37983.068626800276
# ===============================
# 44284.045768926575
# ===============================
# 40195.55404945261
# ===============================
# 35181.60233672497
# ===============================
# 29761.418529999675
# ===============================
# 40087.18743333172
# ===============================
# 48751.78618448848
# ===============================
# 35191.53512146748
# ===============================
# average rmse: 39143.51143872071

# %% [markdown]
# ##3.4 Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = RandomForestRegressor(random_state = 0, n_estimators = 200)
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))
  pred = y_min_max_scaler.inverse_transform(pred)
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 27552.153326892567
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 28621.80285913716
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 23817.95036668299
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 40776.881361803906
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 31622.274948695325
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 27447.221457773543
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 23469.91651273502
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 24493.94355996853
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 37094.35721237885
# ===============================
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 26472.81173709179
# ===============================
# average rmse: 29136.931334315967

# %% [markdown]
# ##3.5 AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor
rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = AdaBoostRegressor(random_state = 0, n_estimators = 200)
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))
  pred = y_min_max_scaler.inverse_transform(pred)
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 31920.705996605775
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 34965.325983329014
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 29774.04593944251
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 43701.873583602035
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 39380.99766277385
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 34484.814550743824
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 31506.68566944809
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 32706.715731086922
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 38152.989426034444
# ===============================
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 35268.19942050678
# ===============================
# average rmse: 35186.235396357326

# %% [markdown]
# ##3.6 XGBoost

# %%
from xgboost import XGBRegressor
rmses = []
for train_index, test_index in kf.split(scaled_X):

  scaled_X_train, scaled_X_test = scaled_X[train_index], scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index], scaled_y[test_index]
  y_test = y[test_index]

  #print(x_train,shape, x_test.shape)
  #print(y_train.shape, y_test.shape)

  #training
  model = XGBRegressor(random_state = 0, n_estimators = 200)
  model = model.fit(scaled_X_train, scaled_y_train)

  #evaluation
  pred = model.predict(scaled_X_test).reshape((-1,1))
  pred = y_min_max_scaler.inverse_transform(pred)
  rmse = np.sqrt(metrics.mean_squared_error(y_test,pred))

  print(rmse)
  print("===============================")
  rmses.append(rmse)
print("average rmse:", np.mean(rmses))
models.append(np.mean(rmses))
# Out:
# [12:28:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 24405.561644290126
# ===============================
# [12:28:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 26709.98444825083
# ===============================
# [12:28:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 25161.113550953
# ===============================
# [12:28:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 37756.76998222338
# ===============================
# [12:28:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 30804.731397426076
# ===============================
# [12:28:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 26356.734412051854
# ===============================
# [12:28:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 29570.918088054954
# ===============================
# [12:28:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 24383.726575024124
# ===============================
# [12:28:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 28993.890495956213
# ===============================
# [12:28:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 25574.58614570736
# ===============================
# average rmse: 27971.801673993796

# %% [markdown]
# #4.모델 비교 및 결론

# %%
model_compare = pd.DataFrame(models, columns = ['RMSE'],index=['Linear','MLP','Decision Tree','Random Forest','AdaBoost','XGBoost'])
model_compare.sort_values(by = 'RMSE',ascending=True)
# Out:
#                        RMSE
# XGBoost        27971.801674
# Random Forest  29136.931334
# MLP            33029.414751
# AdaBoost       35186.235396
# Decision Tree  39143.511439
# Linear         79020.252141

# %% [markdown]
# XGBoost를 사용했을때 오차가 제일 낮게 나왔음

# %% [markdown]
# #5.Submission

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]

# %%
#1. remove missing data feature
#train에서 missing data에서 없앤 feature를 test에서도 똑같이 없애줘야함
#규격을 맞춰줘야함
df_test = df_test.drop(df_missing.index.tolist(), axis=1)

# %%
 df_test
# Out:
#         Id  MSSubClass MSZoning  LotArea  ... MoSold YrSold SaleType SaleCondition
# 0     1461          20       RH    11622  ...      6   2010       WD        Normal
# 1     1462          20       RL    14267  ...      6   2010       WD        Normal
# 2     1463          60       RL    13830  ...      3   2010       WD        Normal
# 3     1464          60       RL     9978  ...      6   2010       WD        Normal
# 4     1465         120       RL     5005  ...      1   2010       WD        Normal
# ...    ...         ...      ...      ...  ...    ...    ...      ...           ...
# 1454  2915         160       RM     1936  ...      6   2006       WD        Normal
# 1455  2916         160       RM     1894  ...      4   2006       WD       Abnorml
# 1456  2917          20       RL    20000  ...      9   2006       WD       Abnorml
# 1457  2918          85       RL    10441  ...      7   2006       WD        Normal
# 1458  2919          60       RL     9627  ...     11   2006       WD        Normal
#
# [1459 rows x 61 columns]

# %%
#missing data가 있는지 재 확인
df_test.isnull().sum()
#df_train 과 다르게 필요한 feature에서도 missing data가 존재하고 있음
# Out:
# Id               0
# MSSubClass       0
# MSZoning         4
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         1
# SaleCondition    0
# Length: 61, dtype: int64

# %%
category_maps
# Out:
# [{'C (all)': 3, 'FV': 4, 'RH': 5, 'RL': 1, 'RM': 2},
#  {'Grvl': 2, 'Pave': 1},
#  {'IR1': 2, 'IR2': 3, 'IR3': 4, 'Reg': 1},
#  {'Bnk': 2, 'HLS': 4, 'Low': 3, 'Lvl': 1},
#  {'AllPub': 1, 'NoSeWa': 2},
#  {'Corner': 3, 'CulDSac': 4, 'FR2': 2, 'FR3': 5, 'Inside': 1},
#  {'Gtl': 1, 'Mod': 2, 'Sev': 3},
#  {'Blmngtn': 22,
#   'Blueste': 25,
#   'BrDale': 23,
#   'BrkSide': 9,
#   'ClearCr': 20,
#   'CollgCr': 1,
#   'Crawfor': 3,
#   'Edwards': 16,
#   'Gilbert': 18,
#   'IDOTRR': 14,
#   'MeadowV': 15,
#   'Mitchel': 5,
#   'NAmes': 12,
#   'NPkVill': 21,
#   'NWAmes': 7,
#   'NoRidge': 4,
#   'NridgHt': 11,
#   'OldTown': 8,
#   'SWISU': 24,
#   'Sawyer': 10,
#   'SawyerW': 13,
#   'Somerst': 6,
#   'StoneBr': 19,
#   'Timber': 17,
#   'Veenker': 2},
#  {'Artery': 4,
#   'Feedr': 2,
#   'Norm': 1,
#   'PosA': 8,
#   'PosN': 3,
#   'RRAe': 5,
#   'RRAn': 7,
#   'RRNe': 9,
#   'RRNn': 6},
#  {'Artery': 2,
#   'Feedr': 4,
#   'Norm': 1,
#   'PosA': 6,
#   'PosN': 5,
#   'RRAe': 8,
#   'RRAn': 7,
#   'RRNn': 3},
#  {'1Fam': 1, '2fmCon': 2, 'Duplex': 3, 'Twnhs': 5, 'TwnhsE': 4},
#  {'1.5Fin': 3,
#   '1.5Unf': 4,
#   '1Story': 2,
#   '2.5Fin': 8,
#   '2.5Unf': 7,
#   '2Story': 1,
#   'SFoyer': 5,
#   'SLvl': 6},
#  {'Flat': 5, 'Gable': 1, 'Gambrel': 3, 'Hip': 2, 'Mansard': 4, 'Shed': 6},
#  {'ClyTile': 8,
#   'CompShg': 1,
#   'Membran': 5,
#   'Metal': 3,
#   'Roll': 7,
#   'Tar&Grv': 6,
#   'WdShake': 4,
#   'WdShngl': 2},
#  {'AsbShng': 9,
#   'AsphShn': 12,
#   'BrkComm': 11,
#   'BrkFace': 5,
#   'CBlock': 15,
#   'CemntBd': 7,
#   'HdBoard': 4,
#   'ImStucc': 14,
#   'MetalSd': 2,
#   'Plywood': 8,
#   'Stone': 13,
#   'Stucco': 10,
#   'VinylSd': 1,
#   'Wd Sdng': 3,
#   'WdShing': 6},
#  {'AsbShng': 10,
#   'AsphShn': 13,
#   'Brk Cmn': 11,
#   'BrkFace': 8,
#   'CBlock': 16,
#   'CmentBd': 7,
#   'HdBoard': 4,
#   'ImStucc': 12,
#   'MetalSd': 2,
#   'Other': 15,
#   'Plywood': 5,
#   'Stone': 14,
#   'Stucco': 9,
#   'VinylSd': 1,
#   'Wd Sdng': 6,
#   'Wd Shng': 3},
#  {'Ex': 3, 'Fa': 4, 'Gd': 1, 'TA': 2},
#  {'Ex': 5, 'Fa': 3, 'Gd': 2, 'Po': 4, 'TA': 1},
#  {'BrkTil': 3, 'CBlock': 2, 'PConc': 1, 'Slab': 5, 'Stone': 6, 'Wood': 4},
#  {'Floor': 6, 'GasA': 1, 'GasW': 2, 'Grav': 3, 'OthW': 5, 'Wall': 4},
#  {'Ex': 1, 'Fa': 4, 'Gd': 2, 'Po': 5, 'TA': 3},
#  {'N': 2, 'Y': 1},
#  {'Ex': 3, 'Fa': 4, 'Gd': 1, 'TA': 2},
#  {'Maj1': 3, 'Maj2': 6, 'Min1': 2, 'Min2': 4, 'Mod': 5, 'Sev': 7, 'Typ': 1},
#  {'N': 2, 'P': 3, 'Y': 1},
#  {'COD': 3,
#   'CWD': 6,
#   'Con': 8,
#   'ConLD': 4,
#   'ConLI': 5,
#   'ConLw': 7,
#   'New': 2,
#   'Oth': 9,
#   'WD': 1},
#  {'Abnorml': 2,
#   'AdjLand': 4,
#   'Alloca': 5,
#   'Family': 6,
#   'Normal': 1,
#   'Partial': 3}]

# %%
def category_to_number(x, category_map):
  if x[feature_name] in category_map:
    return category_map[x[feature_name]]
  else:
    0

# %%
for i, feature_name in enumerate(categorical):
  rank_feature_name = feature_name + '_rank'
  category_map = category_maps[i]

  #.apply는 row한줄 한줄씩 내려가면서 적용하겠다는 것임
  df_test[rank_feature_name] = df_test.apply(lambda x : category_to_number(x, category_map),axis=1)

# %%
df_processed_test = df_test[rank_features + numeric]

# %%
df_processed_test
# Out:
#       OpenPorchSF  2ndFlrSF  WoodDeckSF  ...  GarageCars  GrLivArea  OverallQual
# 0               0         0         140  ...         1.0        896            5
# 1              36         0         393  ...         1.0       1329            6
# 2              34       701         212  ...         2.0       1629            5
# 3              36       678         360  ...         2.0       1604            6
# 4              82         0           0  ...         2.0       1280            8
# ...           ...       ...         ...  ...         ...        ...          ...
# 1454            0       546           0  ...         0.0       1092            4
# 1455           24       546           0  ...         1.0       1092            4
# 1456            0         0         474  ...         2.0       1224            5
# 1457           32         0          80  ...         0.0        970            5
# 1458           48      1004         190  ...         3.0       2000            7
#
# [1459 rows x 15 columns]

# %%
df_features[-NUM_FEATURES-1:-1].index.tolist()
# Out:
# ['OpenPorchSF',
#  '2ndFlrSF',
#  'WoodDeckSF',
#  'BsmtFinSF1',
#  'Fireplaces',
#  'YearRemodAdd',
#  'YearBuilt',
#  'TotRmsAbvGrd',
#  'FullBath',
#  '1stFlrSF',
#  'TotalBsmtSF',
#  'GarageArea',
#  'GarageCars',
#  'GrLivArea',
#  'OverallQual']

# %%
df_processed_test = df_processed_test[df_features[-NUM_FEATURES-1:-1].index.tolist()]

# %%
df_processed_test.isnull().sum()
#결측값때문에 뒤의 model stacking 부분의 randomforest에서 학습이 안됨, 처리해야됨
# Out:
# OpenPorchSF     0
# 2ndFlrSF        0
# WoodDeckSF      0
# BsmtFinSF1      0
# Fireplaces      0
# YearRemodAdd    0
# YearBuilt       0
# TotRmsAbvGrd    0
# FullBath        0
# 1stFlrSF        0
# TotalBsmtSF     0
# GarageArea      0
# GarageCars      0
# GrLivArea       0
# OverallQual     0
# dtype: int64

# %%
def fill_out_na(df,feature):
  df[feature].fillna(df[feature].mean(),inplace=True)

# %%
fill_out_na(df_processed_test,'TotalBsmtSF')
fill_out_na(df_processed_test,'GarageArea')
fill_out_na(df_processed_test,'GarageCars')

# %%
scaled_X_test = X_min_max_scaler.transform(df_processed_test)

# %%
scaled_X_test.shape
# Out:
# (1459, 15)

# %%
scaled_X_test
# Out:
# array([[0.        , 0.        , 0.16336056, ..., 0.25      , 0.10587792,
#         0.44444444],
#        [0.06581353, 0.        , 0.45857643, ..., 0.25      , 0.1874529 ,
#         0.55555556],
#        [0.06215722, 0.33946731, 0.24737456, ..., 0.5       , 0.24397136,
#         0.44444444],
#        ...,
#        [0.        , 0.        , 0.55309218, ..., 0.5       , 0.16767144,
#         0.44444444],
#        [0.05850091, 0.        , 0.09334889, ..., 0.        , 0.11981914,
#         0.44444444],
#        [0.08775137, 0.48619855, 0.22170362, ..., 0.75      , 0.31386586,
#         0.66666667]])

# %%
#predict
pred = model.predict(scaled_X_test).reshape((-1,1))
pred = y_min_max_scaler.inverse_transform(pred)

# %%
#submission 양식을 맞추기 위해서 틀을 만듬
df_submission = pd.DataFrame(columns = ['Id','SalePrice'])

# %%
df_submission['Id'] = np.arange(1461,2919+1)

# %%
df_submission['SalePrice'] = pred

# %%
df_submission
# Out:
#         Id      SalePrice
# 0     1461  123835.515625
# 1     1462  153684.234375
# 2     1463  178128.609375
# 3     1464  181578.453125
# 4     1465  194954.000000
# ...    ...            ...
# 1454  2915   67627.562500
# 1455  2916   85631.328125
# 1456  2917  171567.093750
# 1457  2918  118583.601562
# 1458  2919  240366.859375
#
# [1459 rows x 2 columns]

# %%
df_submission.to_csv('submission_xgboost_2.csv',index=False)

# %% [markdown]
# #6.Model Stacking

# %%
level_1_preds = [] #(146,2)*10

for train_index, test_index in kf.split(scaled_X):
  scaled_X_train, scaled_X_test = scaled_X[train_index],scaled_X[test_index]
  scaled_y_train, scaled_y_test = scaled_y[train_index],scaled_y[test_index]
  y_test = y[test_index]

  #Train
  #1.XGBoost
  xgb_model = XGBRegressor(n_estimators=300)
  xgb_model = xgb_model.fit(scaled_X_train, scaled_y_train)

  #2.Random Forest
  rf_model = RandomForestRegressor(random_state=0,n_estimators=100)
  rf_model = rf_model.fit(scaled_X_train, scaled_y_train)

  #3.MLP
  #얘는 학습시키는데 너무 오래걸리니까 시간 관계상 패스

  #predict
  #1.XGBoost
  xgb_pred = xgb_model.predict(scaled_X_test).reshape((-1,1))
  print(xgb_pred.shape)

  #2.Random Forest
  rf_pred = rf_model.predict(scaled_X_test).reshape((-1,1))
  print(rf_pred.shape)

  #Concatenate---> 두 모델의 예측 결과를 옆으로 쌓아야함 (146,1)+(146,1)===>(146,2)
  pred = np.concatenate([xgb_pred, rf_pred], axis =1)
  print(pred.shape)

  print("----------------------------------")
  
  level_1_preds.append(pred)
# Out:
# [12:39:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------
# [12:39:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------
# [12:39:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------
# [12:39:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------
# [12:39:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------
# [12:39:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------
# [12:39:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------
# [12:39:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------
# [12:39:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------
# [12:39:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   from ipykernel import kernelapp as app
# (146, 1)
# (146, 1)
# (146, 2)
# ----------------------------------

# %%
level_1_preds[0].shape
# Out:
# (146, 2)

# %%
#결국 하고 싶은 것은 (146,2)*10 ===>(146*10,2)
level_1_preds = np.concatenate(level_1_preds, axis =0)

# %%
level_1_preds.shape
# Out:
# (1460, 2)

# %% [markdown]
# 결국 여기서 하고 싶은 것은
#
# X:(1460,60)-->XGBoost ->(1460,1)
#
# X:(1460,60)-->Random Forest ->(1460,1)
# ->stacking
# (level 1) (1460,2) --> level 2 model-->(1460,1)---> Kaggle

# %% [markdown]
# ##Train level 2 model

# %%
scaled_y.shape
# Out:
# (1460, 1)

# %%
#training
level_2_model = XGBRegressor()
level_2_model = level_2_model.fit(level_1_preds, scaled_y)
# Out:
# [13:05:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %% [markdown]
# ##predict using model-stacking

# %%
xgb_pred = xgb_model.predict(scaled_X_test).reshape((-1,1))
rf_pred = rf_model.predict(scaled_X_test).reshape((-1,1))

# %%
xgb_pred.shape, rf_pred.shape
# Out:
# ((1459, 1), (1459, 1))

# %%
level_2_input = np.concatenate([xgb_pred,rf_pred],axis=1)

# %%
level_2_input.shape
# Out:
# (1459, 2)

# %%
pred = level_2_model.predict(level_2_input).reshape((-1,1))
pred = y_min_max_scaler.inverse_transform(pred)

# %%
pred[:5]
# Out:
# array([[122560.586],
#        [147039.25 ],
#        [176856.23 ],
#        [183431.52 ],
#        [207453.02 ]], dtype=float32)

# %% [markdown]
# ##Make Kaggle submission file

# %%
df_submission = pd.DataFrame(columns = ['Id','SalePrice'])
df_submission['Id'] = np.arange(1461,2919+1)
df_submission['SalePrice'] = pred
print(df_submission)
df_submission.to_csv('submission_model_stacking_2.csv',index=False)
# Out:
#         Id      SalePrice
# 0     1461  122560.585938
# 1     1462  147039.250000
# 2     1463  176856.234375
# 3     1464  183431.515625
# 4     1465  207453.015625
# ...    ...            ...
# 1454  2915   76190.617188
# 1455  2916   78326.039062
# 1456  2917  169829.843750
# 1457  2918  116733.757812
# 1458  2919  237819.015625
#
# [1459 rows x 2 columns]
